# %%
import pandas as pd

# %%
import numpy as np

# %%
path = 'C:\\Users\\l1f18bscs0496\\Desktop\\auto.csv'
df = pd.read_csv(path,header=None)

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns = headers
df.replace("?", np.nan, inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
import matplotlib as plt
from matplotlib import pyplot

# %%
plt.pyplot.hist(df['num-of-doors'].value_counts())
# Out:
# (array([1., 0., 0., 0., 0., 0., 0., 1., 0., 1.]),
#  array([  2. ,  13.2,  24.4,  35.6,  46.8,  58. ,  69.2,  80.4,  91.6,
#         102.8, 114. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pyplot.hist(df['num-of-doors'],color="cyan",ec="red")
# Out:
# (array([ 89.,   0.,   0.,   0.,   0., 114.,   0.,   0.,   0.,   2.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pyplot.title("Programing for big data")
plt.pyplot.xlabel("Frequency")
plt.pyplot.ylabel("Category")
plt.pyplot.hist(df['num-of-doors'],color="cyan",ec="red")
# Out:
# (array([ 89.,   0.,   0.,   0.,   0., 114.,   0.,   0.,   0.,   2.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            0
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#BINNING
#convertig numarical value into catagorical value is called binning

# %%
cat=['low',"av","hi"]
df.replace("?", np.nan, inplace=True)
m=df['horsepower'].astype('float').mean()
df['horsepower'].replace(np.nan, m, inplace=True)

# %%
df['horsepower']=df["horsepower"].astype("int")
s=np.linspace(df["horsepower"].min(),df["horsepower"].max(),4)

# %%
print(s)
df["horsepower"].head()
# Out:
# [ 48. 128. 208. 288.]
# 0    111
# 1    111
# 2    154
# 3    102
# 4    115
# Name: horsepower, dtype: int32

# %%
df["horsepower-bin"]=pd.cut(df["horsepower"],s,labels=cat,include_lowest=True)

# %%
df[["horsepower","horsepower-bin"]].head(20)
# Out:
#     horsepower horsepower-bin
# 0          111            low
# 1          111            low
# 2          154             av
# 3          102            low
# 4          115            low
# 5          110            low
# 6          110            low
# 7          110            low
# 8          140             av
# 9          160             av
# 10         101            low
# 11         101            low
# 12         121            low
# 13         121            low
# 14         121            low
# 15         182             av
# 16         182             av
# 17         182             av
# 18          48            low
# 19          70            low
